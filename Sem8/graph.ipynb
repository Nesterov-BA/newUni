# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import cm
t = []
x = []
plt.style.use('ggplot')
df = pd.read_csv('output0.000000.csv')
t.append(df['t'].to_numpy())
x.append(df['x'].to_numpy())
df = pd.read_csv('output0.100000.csv')
t.append(df['t'].to_numpy())
x.append(df['x'].to_numpy())
df = pd.read_csv('output1.000000.csv')
t.append(df['t'].to_numpy())
x.append(df['x'].to_numpy())
df = pd.read_csv('output10.000000.csv')
t.append(df['t'].to_numpy())
x.append(df['x'].to_numpy())

# %%
xn = 5*np.power(t[0], 4)/4-5*np.power(t[0], 3)+9*np.power(t[0], 2)/2+t[0]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[0], x[0])
ax.set_xlabel('t')
ax.set_ylabel("x")
#plt.axis('euql')
plt.axis('square')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[1], x[1])
ax.plot(t[1], x[1])
ax.set_xlabel('t')
ax.set_ylabel("x")
#plt.axis('euql')
plt.axis('square')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[2], x[2])
ax.plot(t[2], x[2])
ax.plot(t[2], x[2])
ax.set_xlabel('t')
ax.set_ylabel("x")
#plt.axis('euql')
plt.axis('square')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[3], x[3])
ax.plot(t[3], x[3])
ax.plot(t[3], x[3])
ax.plot(t[3], x[3])
ax.set_xlabel('t')
ax.set_ylabel("x")
#plt.axis('euql')
plt.axis('square')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
for i in range(4):
    ax.plot(t[i], x[i])
ax.set_xlabel('t')
ax.set_ylabel("x")
#plt.axis('euql')
plt.axis('square')
plt.show()

# %%
a=1
-((840*(70 + 11*a))/(1960 + 777*a + 5*a*a))
# Out:
# -24.814004376367613

# %%
(35*(504 + 125*a))/(1960 + 777*a + 5*a*a)
# Out:
# 8.028811086797958
