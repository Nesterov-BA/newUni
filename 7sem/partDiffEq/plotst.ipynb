# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Function to read data from file and return x, y, z coordinates
def read_data(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
    data = [list(map(float, line.split())) for line in lines]
    return zip(*data)

# Read the data from the file
x, y, z = read_data('data.txt')

# Create a  3D scatter plot
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from scipy.interpolate import griddata

# Function to read data from file and return x, y, z coordinates
def read_data(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
    data = [list(map(float, line.split())) for line in lines]
    return zip(*data)

# Read the data from the file
x, y, z = read_data('data.txt')

# Function to plot data
def plot_data(x, y, z, interpolated=False):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    if interpolated:
        # Define a grid of points where you want to interpolate the data
        grid_x, grid_y = np.mgrid[min(x):max(x):100j, min(y):max(y):100j]

        # Interpolate the data onto the grid
        grid_z = griddata((x, y), z, (grid_x, grid_y), method='cubic')

        # Create a surface plot
        ax.plot_surface(grid_x, grid_y, grid_z, cmap='viridis')
    else:
        # Create a  3D scatter plot
        ax.scatter(x, y, z)

    # Set labels for the axes
    ax.set_xlabel('X')
    ax.set_ylabel('T')
    ax.set_zlabel('U')

    # Show the plot
    plt.show()

# Plot the data as a scatter plot
plot_data(x, y, z, interpolated=False)

# Plot the data as an interpolated surface plot
plot_data(x, y, z, interpolated=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to read data from file and return x, y coordinates
def read_data(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
    data = [list(map(float, line.split())) for line in lines]
    return zip(*data)

# Read the data from the file
x, y = read_data('f.txt')

# Plot the data
plt.plot(x, y, marker='o')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Function Plot')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to read data from file and return x, y, z coordinates
def read_data(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
    data = [list(map(float, line.split())) for line in lines]
    return zip(*data)

# Read the data from the file
x, y, z = read_data('data.txt')

# Convert to numpy arrays for easier manipulation
x = np.array(x)
y = np.array(y)
z = np.array(z)

size = y.size

# %%
# Set the fixed value for the second coordinate
fixed_y =  y[size-1]

# Filter the data for the fixed y value
filtered_x = x[y == fixed_y]
filtered_z = z[y == fixed_y]

# Plot the filtered data
plt.plot(filtered_x, filtered_z, marker='o')
plt.xlabel('X-axis')
plt.ylabel('Z-axis')
plt.title('Function Plot with Fixed Y')
plt.grid(True)
plt.show()
